# %% [markdown]
# <a href="https://colab.research.google.com/github/marjoriedowns/FISC-0746-estructuras-discretas-para-la-computacion/blob/master/Lab11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import defaultdict, namedtuple, Counter, deque
import csv
import random
from urllib.request import urlretrieve

# %%
pelicula_data = 'https://raw.githubusercontent.com/skielosky/FISC-0746-estructura-discretas-computacion-2019/master/laboratorios/secuencias/peliculas_metadata.csv'
pelicula_csv = 'movies.csv'
urlretrieve(pelicula_data, pelicula_csv)
# Out:
# ('movies.csv', <http.client.HTTPMessage at 0x7f408a79b4a8>)

# %%
pelicula = namedtuple('Peliculas', 'title year score')

# %%
def obtener_peliculas_por_director(data=pelicula_csv):
    """Extracts all movies from csv and stores them in a dictionary
       where keys are directors, and values is a list of movies (named tuples)"""
    directors = defaultdict(list)
    with open(data, encoding='utf-8') as f:
        for line in csv.DictReader(f):
            try:
                director = line['director_name']
                movie = line['movie_title'].replace('\xa0', '')
                year = int(line['title_year'])
                score = float(line['imdb_score'])
            except ValueError:
                continue

            m = pelicula(title=movie, year=year, score=score)
            directors[director].append(m)

    return directors

# %%
directores = obtener_peliculas_por_director()

# %% [markdown]
# ## Tarea 01
# 1.	Por Director: Nombre, Año y Rating de la película con mejor Rating
# 2.	Por Director: promedio de rating
# 3.	Director con el mejor rating
# 4.	Lista de películas estrenadas en el 2018
# 5.	Mejor Película del 2018
# 6.	Director con el mejor rating en el 2018

# %% [markdown]
# #Tarea 1
# * Por Director: Nombre, Años, y raiting de la pelicula con mejor raiting

# %%
b=0

# %%
for director, peliculas in directores.items():
  print(director)
  b=0
  c = ""
  a = ""
  for peliculas in peliculas:
    if(peliculas[2]>b):
      a = peliculas[0]
      b = peliculas[2]
      c = peliculas[1]
  print(a)
  print(c)
  print(b)
  print("*****************")
# Out:
# James Cameron
# Terminator 2: Judgment Day
# 1991
# 8.5
# *****************
# Gore Verbinski
# Pirates of the Caribbean: The Curse of the Black Pearl
# 2003
# 8.1
# *****************
# Sam Mendes
# American Beauty
# 1999
# 8.4
# *****************
# Christopher Nolan
# The Dark Knight
# 2008
# 9.0
# *****************
# Andrew Stanton
# WALL·E
# 2008
# 8.4
# *****************
# Sam Raimi
# Evil Dead II
# 1987
# 7.8
# *****************
# Nathan Greno
# Tangled
# 2010
# 7.8
# *****************
# Joss Whedon
# The Avengers
# 2012
# 8.1
# *****************
# David Yates
# Harry Potter and the Half-Blood Prince
# 2009
# 7.5
# *****************
# Zack Snyder
# Watchmen
# 2009
# 7.7
# *****************
# Bryan Singer
# The Usual Suspects
# 1995
# 8.6
# *****************
# Marc Forster
# Finding Neverland
# 2004
# 7.8
# *****************
# Andrew Adamson
# Shrek
# 2001
# 7.9
# *****************
# Rob Marshall
# Memoirs of a Geisha
# 2005
# 7.3
# *****************
# Barry Sonnenfeld
# ...

# %% [markdown]
#  # Tarea 2
#  * Promedio de Raiting

# %%
for director, peliculas in directores.items():
  print(director)
  b =0 
  c =0
  d =0
  
  for peliculas in peliculas:
    b=b+peliculas[2]
    c=c+1
  d=b/c
  
  print("%.2f" % d)
# Out:
# James Cameron
# 7.91
# Gore Verbinski
# 6.99
# Sam Mendes
# 7.50
# Christopher Nolan
# 8.43
# Andrew Stanton
# 7.73
# Sam Raimi
# 6.91
# Nathan Greno
# 7.80
# Joss Whedon
# 7.92
# David Yates
# 7.05
# Zack Snyder
# 7.17
# Bryan Singer
# 7.29
# Marc Forster
# 7.15
# Andrew Adamson
# 7.08
# Rob Marshall
# 6.60
# Barry Sonnenfeld
# 6.46
# Peter Jackson
# 7.68
# Marc Webb
# 7.13
# Ridley Scott
# 7.07
# Chris Weitz
# 6.08
# Anthony Russo
# 7.00
# Peter Berg
# 6.67
# Colin Trevorrow
# 7.00
# Shane Black
# 7.40
# Tim Burton
# 6.93
# Brett Ratner
# 6.41
# Dan Scanlon
# 7.30
# Michael Bay
# 6.64
# Joseph Kosinski
# 7.18
# John Lasseter
# 7.38
# Martin Campbell
# 6.71
# Lee Unkrich
# 8.30
# McG
# 6.08
# James Wan
# 7.20
# J.J. Abrams
# 7.45
# Baz Luhrmann
# 7.12
# Mike Newell
# 6.84
# Guillermo del Toro
# 7.14
# Steven Spielberg
# 7.48
# Peter Sohn
# 6.80
# Mark Andrews
# 7.20
# Justin Lin
# 6.84
# Roland Emmerich
# 6.19
# Robert Zemeckis
# 7.31
# Lana Wachowski
# 6.92
# Pete Docter
# 8.23
# ...

# %% [markdown]
# # Tarea 3
# * Director con el mejor Rating

# %%
f=0
for director, peliculas in directores.items():
  
  b =0 
  c =0
  d =0
  j =0
  di =""
  
  for peliculas in peliculas:
    b=b+peliculas[2]
    c=c+1
  d=b/c
  
  if(d>j):
      j=d
      di=director
  

print("El director con mayor Rating es "+director+" Con: ")
print(j)
# Out:
# El director con mayor Rating es Daniel Hsia Con:
# 6.3

# %% [markdown]
# #Tarea 4
# * Lista de películas estrenadas en el 2016

# %%
print("Peliculas estrenadas en 2016")
for director, peliculas in directores.items():
  
  year =2016 
  c =0
  d =0
  
  for peliculas in peliculas:
    if(year==peliculas[1]):
      
      print(peliculas[0])
      print(peliculas[2])
# Out:
# Peliculas estrenadas en 2016
# The Legend of Tarzan
# 6.6
# The Legend of Tarzan
# 6.6
# Batman v Superman: Dawn of Justice
# 6.9
# X-Men: Apocalypse
# 7.3
# Captain America: Civil War
# 8.2
# 13 Hours
# 7.4
# The Conjuring 2
# 7.8
# The BFG
# 6.8
# Star Trek Beyond
# 7.5
# Independence Day: Resurgence
# 5.5
# The Jungle Book
# 7.8
# The Jungle Book
# 7.8
# Suicide Squad
# 6.9
# Risen
# 6.3
# Godzilla Resurgence
# 8.2
# Godzilla Resurgence
# 8.2
# Alice Through the Looking Glass
# 6.4
# Warcraft
# 7.3
# Ghostbusters
# 5.5
# Ghostbusters
# 5.5
# Kung Fu Panda 3
# 7.2
# Gods of Egypt
# 5.5
# Now You See Me 2
# 6.9
# Jason Bourne
# 7.1
# Allegiant
# 5.8
# Ride Along 2
# 5.9
# The Huntsman: Winter's War
# 6.1
# Teenage Mutant Ninja Turtles: Out of the Shadows
# 6.3
# I Am Wrath
# 5.2
# Zoolander 2
# 4.8
# Ben-Hur
# 6.1
# Ben-Hur
# 6.1
# Ben-Hur
# 6.0
# Free State of Jones
# 6.7
# Race
# 7.1
# The Secret Life of Pets
# 6.8
# The Angry Birds Movie
# 6.3
# The Finest Hours
# 6.8
# ...

# %% [markdown]
# #Tarea5
# * Mejor Película del 2016
